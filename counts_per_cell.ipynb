# %%
import numpy as np
import pandas as pd
import json

# %%
df = pd.read_csv('./data/csv/counts_per_cell.csv', index_col=0)
df
# Out:
#           Cadps2_class  Calb2_class  Cdh13_class  Cnr1_class  Cplx2_class  \
# Bcl11b        0.054908     0.104266     0.086321    0.483205     0.322477
# Cadps2        0.339209     0.590724     1.093951    1.332851     2.092297
# Calb1         0.034809     1.606515     0.000000    0.000951     0.023600
# Calb2         0.106294    11.515027     0.034892    0.662730     0.054051
# Cck           0.018938     0.104521     0.000000    0.079063     0.006763
# ...                ...          ...          ...         ...          ...
# Thsd7a        0.144937     0.650234     0.082966    1.502181     0.585505
# Trp53i11      1.265826     0.739746     6.186294    1.034868     0.074155
# Vip           0.000048     0.000133     0.000000    0.071806     0.059940
# Wfs1          0.515265     0.339929     0.370756    0.563950     1.156942
# Yjefn3        0.002777     0.049982     0.071255    0.072545     0.026690
#
#           Cryab_class  Cxcl14_class  Gad1_class  Id2_class  Lhx6_class  ...  \
# Bcl11b       0.209349      0.062963    0.091773   0.033064    0.379200  ...
# Cadps2       0.795249      2.480518    1.044415   0.239843    3.101091  ...
# Calb1        0.030112      0.088925    0.031391   0.011133    0.041190  ...
# Calb2        0.000000      2.382713    0.015636   0.017985    0.076606  ...
# Cck          0.001185      0.075808    0.046672   0.000000    0.000565  ...
# ...               ...           ...         ...        ...         ...  ...
# Thsd7a       0.966471      0.254044    1.248456   0.072394    1.348837  ...
# Trp53i11     0.325907      0.629427    0.231650   0.055728    0.857341  ...
# Vip          0.001360      0.127099    0.000000   0.003941    0.000000  ...
# Wfs1         0.593892      1.118229    0.284304   1.323083    0.851645  ...
# Yjefn3       0.000000      0.000000    0.000035   0.010687    0.087038  ...
#
#           Plp1_class  Pnoc_class  Pvalb_class  Reln_class  Rgs4_class  \
# Bcl11b      0.051007    0.355366     0.524130    0.352729    0.026043
# Cadps2      0.308708    0.711269     3.208460    0.521245    0.972728
# Calb1       0.010698    0.000000     0.000000    0.030077    0.222806
# Calb2       0.126480    0.046100     0.000533    0.419178    4.141085
# Cck         0.010520    0.031172     0.347927    0.000000    0.171279
# ...              ...         ...          ...         ...         ...
# Thsd7a      0.116398    0.006052     2.002090    0.935246    0.072056
# Trp53i11    0.096325    0.052148     1.236485    0.352857    1.083609
# Vip         0.005882    0.011770     0.000000    0.054436    0.018399
# Wfs1        0.279354    0.424374     1.643927    0.272923    0.300420
# Yjefn3      0.006254    0.015958     0.000138    0.063912    0.022404
#
#           Satb1_class  Snca_class  Sncg_class  Sst_class      Zero
# Bcl11b       0.372215    0.618797    0.112237   0.572315  0.021740
# Cadps2       0.706287    2.216661    0.313813   0.126684  0.075536
# Calb1        0.000000    0.090257    0.273113   0.110603  0.007077
# Calb2        0.115424    0.547690    0.641954   1.633563  0.034003
# Cck          0.117123    0.036901    0.131631   0.136407  0.005292
# ...               ...         ...         ...        ...       ...
# Thsd7a       1.555689    0.261484    0.103197   0.589386  0.021763
# Trp53i11     0.534062    0.136395    2.461793   0.741893  0.028654
# Vip          0.000000    0.000000    0.130572   0.190839  0.007095
# Wfs1         0.348098    0.644755    0.531942   0.473411  0.103123
# Yjefn3       0.001042    0.033520    0.000000   0.000000  0.007669
#
# [70 rows x 23 columns]

# %%
df.columns.values
# Out:
# array(['Cadps2_class', 'Calb2_class', 'Cdh13_class', 'Cnr1_class',
#        'Cplx2_class', 'Cryab_class', 'Cxcl14_class', 'Gad1_class',
#        'Id2_class', 'Lhx6_class', 'Pcp4_class', 'Pde1a_class',
#        'Penk_class', 'Plp1_class', 'Pnoc_class', 'Pvalb_class',
#        'Reln_class', 'Rgs4_class', 'Satb1_class', 'Snca_class',
#        'Sncg_class', 'Sst_class', 'Zero'], dtype=object)

# %%
# // {xKey: 1, xLabel: "Astro.1", yKey: 1, yLabel: "Astro.1", val: 0.1904853455312878}
_cols = df.columns.values
_rows = df.index.values

dictlist = []
arr = df.values
for r in range(arr.shape[0]):
    for c in range(arr.shape[1]):
        data = {}
        data['xKey'] = c+1
        data['xLabel'] = _cols[c]
        data['yKey'] = r+1
        data['yLabel'] = _rows[r]
        data['val'] = df.iloc[r, c]
        dictlist.append(data)

# %%
pd.DataFrame(dictlist).to_json('counts_per_cell.json', orient='records')
